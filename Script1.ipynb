# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()

# %%
dataset = pd.read_excel(pwd + "\\Data - Copy of Source.xlsx", sheet_name="Edited_Data")
dataset
# Out:
#         ID           StartDate             EndDate  \
# 0        1 2014-07-10 18:37:00 2014-07-10 18:39:00
# 1        2 2014-07-10 15:54:00 2014-07-10 15:56:00
# 2        3 2014-07-10 15:44:00 2014-07-10 15:49:00
# 3        4 2014-07-10 13:47:00 2014-07-10 13:47:00
# 4        5 2014-07-10 13:13:00 2014-07-10 13:14:00
# ...    ...                 ...                 ...
# 1088  1089 2014-07-09 17:46:00 2014-07-09 17:49:00
# 1089  1090 2014-07-09 17:46:00 2014-07-09 17:49:00
# 1090  1091 2014-07-09 17:46:00 2014-07-09 17:47:00
# 1091  1092 2014-07-09 17:45:00 2014-07-09 17:46:00
# 1092  1093 2014-07-09 17:45:00 2014-07-09 17:46:00
#
#      Which of the following best describes your current relationship status? - Response  \
# 0       Single, but cohabiting with a significant other
# 1       Single, but cohabiting with a significant other
# 2                                               Married
# 3                                               Married
# ...

# %%
dataset_modified = dataset.copy()
dataset_modified
# Out:
#         ID           StartDate             EndDate  \
# 0        1 2014-07-10 18:37:00 2014-07-10 18:39:00
# 1        2 2014-07-10 15:54:00 2014-07-10 15:56:00
# 2        3 2014-07-10 15:44:00 2014-07-10 15:49:00
# 3        4 2014-07-10 13:47:00 2014-07-10 13:47:00
# 4        5 2014-07-10 13:13:00 2014-07-10 13:14:00
# ...    ...                 ...                 ...
# 1088  1089 2014-07-09 17:46:00 2014-07-09 17:49:00
# 1089  1090 2014-07-09 17:46:00 2014-07-09 17:49:00
# 1090  1091 2014-07-09 17:46:00 2014-07-09 17:47:00
# 1091  1092 2014-07-09 17:45:00 2014-07-09 17:46:00
# 1092  1093 2014-07-09 17:45:00 2014-07-09 17:46:00
#
#      Which of the following best describes your current relationship status? - Response  \
# 0       Single, but cohabiting with a significant other
# 1       Single, but cohabiting with a significant other
# 2                                               Married
# 3                                               Married
# ...

# %%
dataset_modified.columns
# Out:
# Index(['ID', 'StartDate', 'EndDate',
#        'Which of the following best describes your current relationship status? - Response',
#        'How long have you been in your current relationship? If you are not currently in a relationship, please answer according to your last relationship. - Response',
#        'When both you and your partner are at home, how often do you sleep in separate beds? - Response',
#        'When you're not sleeping in the same bed as your partner, where do you typically sleep? - Response',
#        'When you're not sleeping in the same bed as your partner, where do you typically sleep? - Other (please specify)',
#        'When you're not sleeping in the same bed, where does your partner typically sleep? - Response',
#        'When you're not sleeping in the same bed, where does your partner typically sleep? - Other (please specify)',
#        'What are the reasons that you sleep in separate beds? Please select all that apply. - One of us snores',
# ...

# %%
drop_list = ['StartDate', 'EndDate']
dataset_modified = dataset_modified.drop(columns=drop_list)
dataset_modified
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 drop_list = ['StartDate', 'EndDate']
# ----> 2 dataset_modified = dataset_modified.drop(columns=drop_list)
#       3 dataset_modified
#
# File c:\Users\Joshkinz\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\Joshkinz\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
id_list = list(dataset_modified.columns[25:])
id_list = ['ID', id_list]
id_list
# Out:
# ['ID', list]

# %%
dataset_modified = dataset_modified.melt()
